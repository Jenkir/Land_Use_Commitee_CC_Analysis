# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv created in notebook "corridors_census_2016.ipynb" and saved in "Resources" folder on my desktop computer
# Save the data from the csv in a variable, "data_2016"
data_2016 = "./CSVs/CommCorr_Census_Stats_2016.csv"

# %%
# Create a dataframe ("df_2016") by reading the variable data from "data_2016"
df_2016 = pd.read_csv(data_2016)
df_2016
# Out:
#                 Corridor  Census_tract        GEOID  Population  \
# 0           Highlandtown         10200  24510010200      3332.0
# 1               Brooklyn         20300  24510020300      3827.0
# 2          E Monument St         40100  24510040100      3868.0
# 3    Hamilton Lauraville         40200  24510040200       835.0
# 4          E Monument St         60200  24510060200      3198.0
# ..                   ...           ...          ...         ...
# 120              Waverly        280302  24510280302      2377.0
# 121              Pimlico        280401  24510280401      3693.0
# 122              Pigtown        280402  24510280402      1762.0
# 123            Belair Rd        280403  24510280403      6001.0
# 124        E Monument St        280404  24510280404      2386.0
#
#      Median household income  Per capita income  Poverty count  Poverty rate  \
# 0                    96171.0            43737.0          354.0          10.6
# ...

# %%
# Add a column for the year "2016" and insert it in the dataframe
df_2016['Year']= "2016"
df_2016.head()
# Out:
#               Corridor  Census_tract        GEOID  Population  \
# 0         Highlandtown         10200  24510010200      3332.0
# 1             Brooklyn         20300  24510020300      3827.0
# 2        E Monument St         40100  24510040100      3868.0
# 3  Hamilton Lauraville         40200  24510040200       835.0
# 4        E Monument St         60200  24510060200      3198.0
#
#    Median household income  Per capita income  Poverty count  Poverty rate  \
# 0                  96171.0            43737.0          354.0          10.6
# 1                 100778.0            80498.0          307.0           8.0
# 2                  55277.0            44017.0         1028.0          26.6
# 3                  52361.0            20935.0          103.0          12.3
# 4                  65294.0            28985.0          757.0          23.7
#
#    Unemployment rate  # employed, age 16+  ...  Pop. 2 or more races  \
# ...

# %%
# remove columns "Census_tract," "GEOID," "Median household income," "poverty rate," and "Unemployment rate"
corridors_2016 = df_2016.drop(["Census_tract", "Per capita income", "GEOID", "Median household income","Poverty rate", "Unemployment rate" ], axis=1)
corridors_2016.head()
# Out:
#               Corridor  Population  Poverty count  # employed, age 16+  \
# 0         Highlandtown      3332.0          354.0               2242.0
# 1             Brooklyn      3827.0          307.0               2901.0
# 2        E Monument St      3868.0         1028.0               2506.0
# 3  Hamilton Lauraville       835.0          103.0                385.0
# 4        E Monument St      3198.0          757.0               1672.0
#
#    Unemployment count  # persons age 25+ graduated high school  \
# 0                29.0                                    315.0
# 1                95.0                                    248.0
# 2               106.0                                    269.0
# 3                13.0                                     16.0
# 4               221.0                                    403.0
#
#    # persons age 25+ with Bachelor's degree  Median age  Pop. white  \
# 0                                     988.0        31.3      2742.0
# ...

# %%
# Use .groupby an .agg to sum the amounts for each corridor so it is easier to run analysis
df_2016_statistics = corridors_2016.groupby(['Corridor'], as_index=False).agg(
    {'Population': sum, 'Poverty count': sum, '# employed, age 16+': sum,'Unemployment count':sum, '# persons age 25+ graduated high school': sum, 
     'Pop. Black': sum, 'Pop. 2 or more races': sum, 'Pop. Hispanic origin': sum, 'Pop. Asian': sum, 
     'Total pop. in occupied housing units by tenure': sum, 'Total owner-occupied units': sum, 'Total renter-occupied units': sum, 'Pop. <18 years': sum,
     'Pop. working age': sum, 'Pop. 65+ years': sum}
)
df_2016_statistics
# Out:
#                Corridor  Population  Poverty count  # employed, age 16+  \
# 0             Belair Rd     35182.0         6387.0              14865.0
# 1              Brooklyn     14553.0         3468.0               7168.0
# 2         E Monument St     48071.0        12399.0              21030.0
# 3             Greektown     13212.0         2640.0               5915.0
# 4   Hamilton Lauraville     36249.0         5633.0              17595.0
# 5               Hampden     23691.0         2424.0              11189.0
# 6          Highlandtown     27255.0         4991.0              13833.0
# 7             Irvington     11506.0         1926.0               5901.0
# 8             North Ave     15155.0         4522.0               5237.0
# 9          Park Heights     15668.0         4736.0               6328.0
# 10             Penn Ave     62734.0        17405.0              25522.0
# 11              Pigtown     23699.0         5782.0               9940.0
# ...

# %%
# Show corridor with lowest population
df_2016_statistics[ df_2016_statistics['Population'] == df_2016_statistics['Population'].min()]
# Out:
#     Corridor  Population  Poverty count  # employed, age 16+  \
# 7  Irvington     11506.0         1926.0               5901.0
#
#    Unemployment count  # persons age 25+ graduated high school  Pop. Black  \
# 7               377.0                                   2287.0      7187.0
#
#    Pop. 2 or more races  Pop. Hispanic origin  Pop. Asian  \
# 7                 197.0                 401.0       257.0
#
#    Total pop. in occupied housing units by tenure  Total owner-occupied units  \
# 7                                          5605.0                      2219.0
#
#    Total renter-occupied units  Pop. <18 years  Pop. working age  \
# 7                       2597.0          2162.0            8178.0
#
#    Pop. 65+ years
# 7          1166.0

# %%
# Show corridor with lowest working age population
df_2016_statistics[ df_2016_statistics['Pop. working age'] == df_2016_statistics['Pop. working age'].min()]
# Out:
#     Corridor  Population  Poverty count  # employed, age 16+  \
# 3  Greektown     13212.0         2640.0               5915.0
#
#    Unemployment count  # persons age 25+ graduated high school  Pop. Black  \
# 3               439.0                                   1840.0      3119.0
#
#    Pop. 2 or more races  Pop. Hispanic origin  Pop. Asian  \
# 3                 476.0                2943.0       367.0
#
#    Total pop. in occupied housing units by tenure  Total owner-occupied units  \
# 3                                          5929.0                      2381.0
#
#    Total renter-occupied units  Pop. <18 years  Pop. working age  \
# 3                       2429.0          3645.0            7924.0
#
#    Pop. 65+ years
# 3          1643.0

# %%
# Show corridor with largest # of working age population
df_2016_statistics[ df_2016_statistics['Pop. working age'] == df_2016_statistics['Pop. working age'].max()]
# Out:
#     Corridor  Population  Poverty count  # employed, age 16+  \
# 10  Penn Ave     62734.0        17405.0              25522.0
#
#     Unemployment count  # persons age 25+ graduated high school  Pop. Black  \
# 10              3771.0                                  10284.0     47913.0
#
#     Pop. 2 or more races  Pop. Hispanic origin  Pop. Asian  \
# 10                1196.0                1502.0      1371.0
#
#     Total pop. in occupied housing units by tenure  \
# 10                                         24147.0
#
#     Total owner-occupied units  Total renter-occupied units  Pop. <18 years  \
# 10                      9165.0                      16086.0         13447.0
#
#     Pop. working age  Pop. 65+ years
# 10           41822.0          7465.0

# %%
# Replace all NaN values with 0 
#df_2016 = df_2016.fillna(0)

# Create a new column called "Total Wins" and add up each wrestler's wins per year to fill in the values
df_2016["Total Wins"] = combined_wrestlers_df["2013 Wins"] + combined_wrestlers_df["2014 Wins"] + combined_wrestlers_df["2015 Wins"] + combined_wrestlers_df["2016 Wins"]

# Create a new column called "Total Losses" and add up each wrestler's losses per year to fill in the values
combined_wrestlers_df["Total Losses"] = combined_wrestlers_df["2013 Losses"] + combined_wrestlers_df["2014 Losses"] + combined_wrestlers_df["2015 Losses"] + combined_wrestlers_df["2016 Losses"]

# Create a new column called "Total Draws" and add up each wrestler's draws per year to fill in the values
combined_wrestlers_df["Total Draws"] = combined_wrestlers_df["2013 Draws"] + combined_wrestlers_df["2014 Draws"] + combined_wrestlers_df["2015 Draws"] + combined_wrestlers_df["2016 Draws"]

# Create a new column called "Total Matches" and add up the total wins, losses, and draws for each wrestler to fill in the values
combined_wrestlers_df["Total Matches"] = combined_wrestlers_df["Total Wins"] + combined_wrestlers_df["Total Losses"] + combined_wrestlers_df["Total Draws"]

combined_wrestlers_df

# %%
# Helpful website about working with data types: https://pbpython.com/pandas_dtypes.html
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 26 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Corridor                                        125 non-null    object
#  1   Census_tract                                    125 non-null    int64
#  2   GEOID                                           125 non-null    int64
#  3   Population                                      125 non-null    float64
#  4   Median household income                         125 non-null    float64
#  5   Per capita income                               125 non-null    float64
#  6   Poverty count                                   125 non-null    float64
#  7   Poverty rate                                    125 non-null    float64
#  8   Unemployment rate                               125 non-null    float64
# ...

# %%
# Set x axis and tick locations
x_axis = np.arange(len(df_2016))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, df_2016["Population"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, df_2016["Corridor"], rotation="vertical")
# Out:
# ([<matplotlib.axis.XTick at 0x259f0341d88>,
# ...
#  [Text(0.4, 0, 'Highlandtown'),
#   Text(1.4, 0, 'Brooklyn'),
#   Text(2.4, 0, 'E Monument St'),
#   Text(3.4, 0, 'Hamilton Lauraville'),
#   Text(4.4, 0, 'E Monument St'),
#   Text(5.4, 0, 'E Monument St'),
#   Text(6.4, 0, 'Waverly'),
#   Text(7.4, 0, 'E Monument St'),
#   Text(8.4, 0, 'E Monument St'),
#   Text(9.4, 0, 'E Monument St'),
#   Text(10.4, 0, 'E Monument St'),
#   Text(11.4, 0, 'Belair Rd'),
#   Text(12.4, 0, 'Belair Rd'),
#   Text(13.4, 0, 'Hampden'),
#   Text(14.4, 0, 'E Monument St'),
#   Text(15.4, 0, 'E Monument St'),
#   Text(16.4, 0, 'E Monument St'),
#   Text(17.4, 0, 'E Monument St'),
#   Text(18.4, 0, 'Waverly'),
#   Text(19.4, 0, 'Waverly'),
#   Text(20.4, 0, 'Waverly'),
#   Text(21.4, 0, 'North Ave'),
#   Text(22.4, 0, 'Belair Rd'),
#   Text(23.4, 0, 'Waverly'),
#   Text(24.4, 0, 'Penn Ave'),
#   Text(25.4, 0, 'Park Heights'),
#   Text(26.4, 0, 'Waverly'),
#   Text(27.4, 0, 'Waverly'),
# ...

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(df_2016["Population"])+10)
# Out:
# (0.0, 6960.0)

# %%
# Set a Title and labels
plt.title("Population per Corridor - 2016")
plt.xlabel("Corridor")
plt.ylabel("Population")
# Out:
# Text(0, 0.5, 'Population')

# %%
# Save and show the graph
plt.tight_layout()
plt.savefig("Population_2016.png")
plt.show()

# %%
# Using .to_numeric can make it easier to do calculations, if you need to change a data point from an "object," for example
#pd.to_numeric(df_2016['Population'])
# Out:
#               Corridor  Census_tract        GEOID  Population  \
# 0         Highlandtown         10200  24510010200      3332.0
# 1             Brooklyn         20300  24510020300      3827.0
# 2        E Monument St         40100  24510040100      3868.0
# 3  Hamilton Lauraville         40200  24510040200       835.0
# 4        E Monument St         60200  24510060200      3198.0
#
#    Median household income  Per capita income  Poverty count  Poverty rate  \
# 0                  96171.0            43737.0          354.0          10.6
# 1                 100778.0            80498.0          307.0           8.0
# 2                  55277.0            44017.0         1028.0          26.6
# 3                  52361.0            20935.0          103.0          12.3
# 4                  65294.0            28985.0          757.0          23.7
#
#    Unemployment rate  # employed, age 16+  ...  Pop. 2 or more races  \
# ...

# %%
data_2017 = "./CSVs/CommCorr_Census_Stats_2017.csv"
df_2017 = pd.read_csv(data_2017)
df_2017.head()
# Out:
#               Corridor  Census_tract        GEOID  Population  \
# 0         Highlandtown         10200  24510010200      3145.0
# 1             Brooklyn         20300  24510020300      3768.0
# 2        E Monument St         40100  24510040100      4007.0
# 3  Hamilton Lauraville         40200  24510040200       865.0
# 4        E Monument St         60200  24510060200      3075.0
#
#    Median household income  Per capita income  Poverty count  Poverty rate  \
# 0                 109102.0            52527.0          185.0           5.9
# 1                  96667.0            84805.0          336.0           8.9
# 2                  61754.0            47181.0         1006.0          25.1
# 3                  56250.0            18951.0           81.0           9.4
# 4                  66371.0            30821.0          633.0          20.6
#
#    Unemployment rate  # employed, age 16+  ...  Pop. Black  \
# 0                1.1               2327.0  ...       164.0
# ...

# %%
df_2017['Year']= "2017"
df_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 26 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Corridor                                        125 non-null    object
#  1   Census_tract                                    125 non-null    int64
#  2   GEOID                                           125 non-null    int64
#  3   Population                                      125 non-null    float64
#  4   Median household income                         125 non-null    float64
#  5   Per capita income                               125 non-null    float64
#  6   Poverty count                                   125 non-null    float64
#  7   Poverty rate                                    125 non-null    float64
#  8   Unemployment rate                               125 non-null    float64
# ...

# %%
# remove columns "Census_tract," "GEOID," "Median household income," "poverty rate," and "Unemployment rate"
corridors_2017 = df_2017.drop(["Census_tract", "Per capita income", "GEOID", "Median household income","Poverty rate", "Unemployment rate" ], axis=1)

# Use .groupby an .agg to sum the amounts for each corridor so it is easier to run analysis
df_2017_statistics = corridors_2017.groupby(['Corridor'], as_index=False).agg(
    {'Population': sum, 'Poverty count': sum, '# employed, age 16+': sum,'Unemployment count':sum, '# persons age 25+ graduated high school': sum, 
     'Pop. Black': sum, 'Pop. 2 or more races': sum, 'Pop. Hispanic origin': sum, 'Pop. Asian': sum, 
     'Total pop. in occupied housing units by tenure': sum, 'Total owner-occupied units': sum, 'Total renter-occupied units': sum, 'Pop. <18 years': sum,
     'Pop. working age': sum, 'Pop. 65+ years': sum}
)
df_2017_statistics
# Out:
#                Corridor  Population  Poverty count  # employed, age 16+  \
# 0             Belair Rd     35351.0         6752.0              14677.0
# 1              Brooklyn     13679.0         3194.0               6945.0
# 2         E Monument St     48613.0        11716.0              21883.0
# 3             Greektown     13444.0         2431.0               6234.0
# 4   Hamilton Lauraville     37013.0         5866.0              17707.0
# 5               Hampden     23587.0         2467.0              11239.0
# 6          Highlandtown     27384.0         4831.0              14157.0
# 7             Irvington     11311.0         1909.0               5910.0
# 8             North Ave     15855.0         5058.0               5405.0
# 9          Park Heights     15455.0         4157.0               6133.0
# 10             Penn Ave     60838.0        15951.0              25444.0
# 11              Pigtown     23378.0         5574.0              10084.0
# ...

# %%
# Show corridor with lowest population
df_2017_statistics[ df_2017_statistics['Population'] == df_2017_statistics['Population'].min()]
# Out:
#     Corridor  Population  Poverty count  # employed, age 16+  \
# 7  Irvington     11311.0         1909.0               5910.0
#
#    Unemployment count  # persons age 25+ graduated high school  Pop. Black  \
# 7               321.0                                   2285.0      7146.0
#
#    Pop. 2 or more races  Pop. Hispanic origin  Pop. Asian  \
# 7                 148.0                 233.0       346.0
#
#    Total pop. in occupied housing units by tenure  Total owner-occupied units  \
# 7                                          5142.0                      2102.0
#
#    Total renter-occupied units  Pop. <18 years  Pop. working age  \
# 7                       2582.0          1931.0            8193.0
#
#    Pop. 65+ years
# 7          1187.0

# %%
data_2018 = "./CSVs/CommCorr_Census_Stats_2018.csv"
df_2018 = pd.read_csv(data_2018)
df_2018.head()
# Out:
#               Corridor  Census_tract        GEOID  Population  \
# 0         Highlandtown         10200  24510010200      2869.0
# 1             Brooklyn         20300  24510020300      3877.0
# 2        E Monument St         40100  24510040100      4404.0
# 3  Hamilton Lauraville         40200  24510040200       901.0
# 4        E Monument St         60200  24510060200      3241.0
#
#    Median household income  Per capita income  Poverty count  Poverty rate  \
# 0                 107617.0            56058.0          169.0           5.9
# 1                 108516.0            87413.0          359.0           9.3
# 2                  62500.0            49876.0          870.0          19.8
# 3                  34375.0            16596.0           66.0           7.3
# 4                  72465.0            32023.0          864.0          26.7
#
#    Unemployment rate  # employed, age 16+  ...  Pop. Black  \
# 0                1.0               2100.0  ...       107.0
# ...

# %%
df_2018['Year']= "2018"
df_2018.head()
# Out:
#               Corridor  Census_tract        GEOID  Population  \
# 0         Highlandtown         10200  24510010200      2869.0
# 1             Brooklyn         20300  24510020300      3877.0
# 2        E Monument St         40100  24510040100      4404.0
# 3  Hamilton Lauraville         40200  24510040200       901.0
# 4        E Monument St         60200  24510060200      3241.0
#
#    Median household income  Per capita income  Poverty count  Poverty rate  \
# 0                 107617.0            56058.0          169.0           5.9
# 1                 108516.0            87413.0          359.0           9.3
# 2                  62500.0            49876.0          870.0          19.8
# 3                  34375.0            16596.0           66.0           7.3
# 4                  72465.0            32023.0          864.0          26.7
#
#    Unemployment rate  # employed, age 16+  ...  Pop. 2 or more races  \
# ...

# %%
data_2019 = "./CSVs/CommCorr_Census_Stats_2019.csv"
df_2019 = pd.read_csv(data_2019)
df_2019.head()
# Out:
#               Corridor  Census_tract        GEOID  Population  \
# 0         Highlandtown         10200  24510010200      2858.0
# 1             Brooklyn         20300  24510020300      3761.0
# 2        E Monument St         40100  24510040100      5051.0
# 3  Hamilton Lauraville         40200  24510040200       984.0
# 4        E Monument St         60200  24510060200      3037.0
#
#    Median household income  Per capita income  Poverty count  Poverty rate  \
# 0                 106250.0            57925.0          133.0           4.7
# 1                 108026.0            83545.0          342.0           9.1
# 2                  64016.0            50026.0          626.0          12.4
# 3                  43417.0            19148.0           93.0           9.5
# 4                  69034.0            40668.0         1026.0          33.8
#
#    Unemployment rate  # employed, age 16+  ...  Pop. Black  \
# 0                1.3               2086.0  ...       128.0
# ...

# %%
df_2019['Year']= "2019"
df_2019.tail()
# Out:
#           Corridor  Census_tract        GEOID  Population  \
# 120        Waverly        280302  24510280302      2538.0
# 121        Pimlico        280401  24510280401      3269.0
# 122        Pigtown        280402  24510280402      1632.0
# 123      Belair Rd        280403  24510280403      5468.0
# 124  E Monument St        280404  24510280404      2631.0
#
#      Median household income  Per capita income  Poverty count  Poverty rate  \
# 120                  44423.0            24760.0          519.0          20.4
# 121                  46493.0            31029.0          350.0          10.7
# 122                  48750.0            23395.0          262.0          16.1
# 123                  57973.0            34384.0          263.0           4.8
# 124                  39233.0            23113.0          613.0          23.3
#
#      Unemployment rate  # employed, age 16+  ...  Pop. 2 or more races  \
# 120                4.9               1179.0  ...                 209.0
# ...

# %%
data_2020 = "./CSVs/CommCorr_Census_Stats_2020.csv"
df_2020 = pd.read_csv(data_2020)
df_2020.head()
# Out:
#               Corridor  Census_tract        GEOID  Population  \
# 0         Highlandtown         10200  24510010200      2869.0
# 1             Brooklyn         20300  24510020300      3877.0
# 2        E Monument St         40100  24510040100      4404.0
# 3  Hamilton Lauraville         40200  24510040200       901.0
# 4        E Monument St         60200  24510060200      3241.0
#
#    Median household income  Per capita income  Poverty count  Poverty rate  \
# 0                 107617.0            56058.0          169.0           5.9
# 1                 108516.0            87413.0          359.0           9.3
# 2                  62500.0            49876.0          870.0          19.8
# 3                  34375.0            16596.0           66.0           7.3
# 4                  72465.0            32023.0          864.0          26.7
#
#    Unemployment rate  # employed, age 16+  ...  Pop. Black  \
# 0                1.0               2100.0  ...       107.0
# ...

# %%
df_2020['Year']= "2020"
df_2020.head()
# Out:
#               Corridor  Census_tract        GEOID  Population  \
# 0         Highlandtown         10200  24510010200      2869.0
# 1             Brooklyn         20300  24510020300      3877.0
# 2        E Monument St         40100  24510040100      4404.0
# 3  Hamilton Lauraville         40200  24510040200       901.0
# 4        E Monument St         60200  24510060200      3241.0
#
#    Median household income  Per capita income  Poverty count  Poverty rate  \
# 0                 107617.0            56058.0          169.0           5.9
# 1                 108516.0            87413.0          359.0           9.3
# 2                  62500.0            49876.0          870.0          19.8
# 3                  34375.0            16596.0           66.0           7.3
# 4                  72465.0            32023.0          864.0          26.7
#
#    Unemployment rate  # employed, age 16+  ...  Pop. 2 or more races  \
# ...

# %%
# Combine five data frames together; using pd.concat adds each dataframe "below" the previous dataframe
combined = [df_2016, df_2017, df_2018, df_2019, df_2020]
combined_df = pd.concat(combined)
combined_df
# Out:
#                 Corridor  Census_tract        GEOID  Population  \
# 0           Highlandtown         10200  24510010200      3332.0
# 1               Brooklyn         20300  24510020300      3827.0
# 2          E Monument St         40100  24510040100      3868.0
# 3    Hamilton Lauraville         40200  24510040200       835.0
# 4          E Monument St         60200  24510060200      3198.0
# ..                   ...           ...          ...         ...
# 120              Waverly        280302  24510280302      2464.0
# 121              Pimlico        280401  24510280401      3479.0
# 122              Pigtown        280402  24510280402      1634.0
# 123            Belair Rd        280403  24510280403      5264.0
# 124        E Monument St        280404  24510280404      2812.0
#
#      Median household income  Per capita income  Poverty count  Poverty rate  \
# 0                    96171.0            43737.0          354.0          10.6
# ...

# %%
# Split up data into groups based upon 'Corridor'
corridor_stats_df = df_2016.groupby('Corridor')

# Chart data, give it a title, and label the axes
2016_chart = gender_trips.plot(kind="bar", title="Bike Trips by Gender")
gender_chart.set_xlabel("Gender")
gender_chart.set_ylabel("Number of Trips Taken")

plt.show()
plt.tight_layout()

# %%
# Split up our data into groups based upon 'gender'
gender_groups = bike_trips_df.groupby('gender')

# Find out how many of each gender took bike trips
gender_trips = gender_groups['tripduration'].count()

# Drop the 'stoptime' row that is contained within our group
gender_trips = gender_trips.drop(gender_trips.index[3])

# Chart our data, give it a title, and label the axes
gender_chart = gender_trips.plot(kind="bar", title="Bike Trips by Gender")
gender_chart.set_xlabel("Gender")
gender_chart.set_ylabel("Number of Trips Taken")

plt.show()
plt.tight_layout()

# %%
# Set the 'Country Code' to be our index for easy referencing of rows
# combined_unemployed_data = combined_unemployed_data.set_index("Country Code")

# %%
# use .to_csv to create a csv file and save it to your computer
# comment the code below until you are ready to run the numbers and save the data in a csv
# combined_df.to_csv("2016_thru_2020_combined.csv", index = False, header=True)
