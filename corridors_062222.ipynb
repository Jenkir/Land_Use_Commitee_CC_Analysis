# %% [markdown]
# 2019 Census Data for Selected Variables - Baltimore City

# %%
#pip install us

# %%
pip install censusgeocode
# Out:
# Collecting censusgeocode
#   Downloading censusgeocode-0.5.2-py3-none-any.whl (9.2 kB)
# Collecting requests[security]<3,>=2.27.0
#   Downloading requests-2.28.0-py3-none-any.whl (62 kB)
# Note: you may need to restart the kernel to use updated packages.
# Collecting requests-toolbelt<1,>=0.9.0
#   Downloading requests_toolbelt-0.9.1-py2.py3-none-any.whl (54 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from requests[security]<3,>=2.27.0->censusgeocode) (1.25.11)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from requests[security]<3,>=2.27.0->censusgeocode) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from requests[security]<3,>=2.27.0->censusgeocode) (2020.6.20)
# Installing collected packages: charset-normalizer, requests, requests-toolbelt, censusgeocode
#   Attempting uninstall: requests
#     Found existing installation: requests 2.24.0
#     Uninstalling requests-2.24.0:
#       Successfully uninstalled requests-2.24.0
# Successfully installed censusgeocode-0.5.2 charset-normalizer-2.0.12 requests-2.28.0 requests-toolbelt-0.9.1

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
from us import states
import censusdata
import censusgeocode as cg
#import gmaps

# Census & gmaps API Keys
from config import api_key
c = Census(api_key, year=2019)

# Configure gmaps
#gmaps.configure(api_key=gkey)

# %%
# Run Census Search to retrieve data on all states
# Note the addition of "B23025_005E" for unemployment count
census_data = c.acs5.state_county_tract(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E",
                          "B23025_005E",
                          "B08136_003E",
                          "B23025_004E",
                          "B23025_005E",
                          "B15003_017E"), 
                         state_fips = states.MD.fips,
                         county_fips = "510",
                         tract = "*")

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)
census_pd.head()
# Out:
# ---------------------------------------------------------------------------
# CensusException                           Traceback (most recent call last)
# <ipython-input-21-51d02278801c> in <module>
#      11                          state_fips = states.MD.fips,
#      12                          county_fips = "510",
# ---> 13                          tract = "*")
#      14
#      15 # Convert to DataFrame
#
# ~\anaconda3\envs\PythonData\lib\site-packages\census\core.py in wrapper(self, *args, **kwargs)
#      48                 raise UnsupportedYearException(
#      49                     'Geography is not available in {}. Available years include {}'.format(year, _years))
# ---> 50             return func(self, *args, **kwargs)
#      51         return wrapper
#      52     return inner
#
# ~\anaconda3\envs\PythonData\lib\site-packages\census\core.py in state_county_tract(self, fields, state_fips, county_fips, tract, **kwargs)
#     335             'for': 'tract:{}'.format(tract),
#     336             'in': 'state:{} county:{}'.format(state_fips, county_fips),
# --> 337         }, **kwargs)
#     338
#     339     @supported_years()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\census\core.py in get(self, *args, **kwargs)
#     311         self._switch_endpoints(kwargs.get('year', self.default_year))
#     312
# --> 313         return super(ACSClient, self).get(*args, **kwargs)
#     314
#     315
#
# ~\anaconda3\envs\PythonData\lib\site-packages\census\core.py in get(self, fields, geo, year, **kwargs)
#     157         all_results = (self.query(forty_nine_fields, geo, year, sort_by_geoid=sort_by_geoid, **kwargs)
#     158                        for forty_nine_fields in chunks(fields, 49))
# --> 159         merged_results = [merge(result) for result in zip(*all_results)]
#     160
#     161         return merged_results
#
# ~\anaconda3\envs\PythonData\lib\site-packages\census\core.py in <genexpr>(.0)
#     156         sort_by_geoid = len(fields) > 49 and (not year or year > 2009)
#     157         all_results = (self.query(forty_nine_fields, geo, year, sort_by_geoid=sort_by_geoid, **kwargs)
# --> 158                        for forty_nine_fields in chunks(fields, 49))
#     159         merged_results = [merge(result) for result in zip(*all_results)]
#     160
#
# ~\anaconda3\envs\PythonData\lib\site-packages\census\core.py in wrapper(self, *args, **kwargs)
#      58         for _ in range(max(self.retries - 1, 0)):
#      59             try:
# ---> 60                 result = func(self, *args, **kwargs)
#      61             except CensusException as e:
#      62                 if "There was an error while running your query.  We've logged the error and we'll correct it ASAP.  Sorry for the inconvenience." in str(e):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\census\core.py in query(self, fields, geo, year, sort_by_geoid, **kwargs)
#     212
#     213         else:
# --> 214             raise CensusException(resp.text)
#     215
#     216     @lru_cache(maxsize=1024)
#
# CensusException: error: error: unknown variable 'GEOID'

# %%
# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Median Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B08136_003E": "Time spent commuting (minutes)",
                                      "B23025_004E": "Number of Employed, age 16+",
                                      "B23025_005E": "Unemployment Count",
                                      "B15003_017E": "Number of persons age 25+ graduated high school",
                                      "NAME": "Name", "state": "State"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rate"] = 100 * \
    census_pd["Poverty Count"].astype(
        int) / census_pd["Population"].astype(int)

# Add in Employment Rate (Employment Count / Population)
census_pd["Unemployment Rate"] = 100 * \
    census_pd["Unemployment Count"].astype(
        int) / census_pd["Population"].astype(int)

# Final DataFrame
census_pd = census_pd[["State", "Name", "Population", "Median Age", "Median Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rate", "Unemployment Rate", 
                       "Time spent commuting (minutes)","Number of Employed, age 16+", "Unemployment Count",
                      "Number of persons age 25+ graduated high school"]]

census_pd.head()
# Out:
#   State                                            Name  Population  \
# 0    24  Census Tract 2604.03, Baltimore city, Maryland      1764.0
# 1    24     Census Tract 2302, Baltimore city, Maryland      1982.0
# 2    24  Census Tract 2601.02, Baltimore city, Maryland      4775.0
# 3    24  Census Tract 2603.03, Baltimore city, Maryland       969.0
# 4    24     Census Tract 2608, Baltimore city, Maryland      2332.0
#
#    Median Age  Median Household Income  Per Capita Income  Poverty Count  \
# 0        27.9                  31625.0            21744.0          436.0
# 1        30.7                 107391.0            63973.0          151.0
# 2        41.3                  62586.0            25903.0          469.0
# 3        37.0                  17000.0            19562.0          377.0
# 4        36.1                  40795.0            26895.0          481.0
#
#    Poverty Rate  Unemployment Rate  Time spent commuting (minutes)  \
# 0     24.716553           1.927438                             NaN
# 1      7.618567           0.857719                             NaN
# 2      9.821990           3.162304                             NaN
# 3     38.906089           2.063983                             NaN
# 4     20.626072           1.629503                             NaN
#
#    Number of Employed, age 16+  Unemployment Count  \
# 0                        885.0                34.0
# 1                       1500.0                17.0
# 2                       2366.0               151.0
# 3                        286.0                20.0
# 4                       1233.0                38.0
#
#    Number of persons age 25+ graduated high school
# 0                                            450.0
# 1                                             72.0
# 2                                           1231.0
# 3                                            229.0
# 4                                            394.0

# %%
census_pd["Poverty Rate"] = census_pd["Poverty Rate"].astype(float).round(1)
census_pd.head()
# Out:
#   State                                            Name  Population  \
# 0    24  Census Tract 2604.03, Baltimore city, Maryland      1764.0
# 1    24     Census Tract 2302, Baltimore city, Maryland      1982.0
# 2    24  Census Tract 2601.02, Baltimore city, Maryland      4775.0
# 3    24  Census Tract 2603.03, Baltimore city, Maryland       969.0
# 4    24     Census Tract 2608, Baltimore city, Maryland      2332.0
#
#    Median Age  Median Household Income  Per Capita Income  Poverty Count  \
# 0        27.9                  31625.0            21744.0          436.0
# 1        30.7                 107391.0            63973.0          151.0
# 2        41.3                  62586.0            25903.0          469.0
# 3        37.0                  17000.0            19562.0          377.0
# 4        36.1                  40795.0            26895.0          481.0
#
#    Poverty Rate  Unemployment Rate  Time spent commuting (minutes)  \
# 0          24.7           1.927438                             NaN
# 1           7.6           0.857719                             NaN
# 2           9.8           3.162304                             NaN
# 3          38.9           2.063983                             NaN
# 4          20.6           1.629503                             NaN
#
#    Number of Employed, age 16+  Unemployment Count  \
# 0                        885.0                34.0
# 1                       1500.0                17.0
# 2                       2366.0               151.0
# 3                        286.0                20.0
# 4                       1233.0                38.0
#
#    Number of persons age 25+ graduated high school
# 0                                            450.0
# 1                                             72.0
# 2                                           1231.0
# 3                                            229.0
# 4                                            394.0

# %%
census_pd["Unemployment Rate"] = census_pd["Unemployment Rate"].astype(float).round(1)
census_pd.head()
# Out:
#   State                                            Name  Population  \
# 0    24  Census Tract 2604.03, Baltimore city, Maryland      1764.0
# 1    24     Census Tract 2302, Baltimore city, Maryland      1982.0
# 2    24  Census Tract 2601.02, Baltimore city, Maryland      4775.0
# 3    24  Census Tract 2603.03, Baltimore city, Maryland       969.0
# 4    24     Census Tract 2608, Baltimore city, Maryland      2332.0
#
#    Median Age  Median Household Income  Per Capita Income  Poverty Count  \
# 0        27.9                  31625.0            21744.0          436.0
# 1        30.7                 107391.0            63973.0          151.0
# 2        41.3                  62586.0            25903.0          469.0
# 3        37.0                  17000.0            19562.0          377.0
# 4        36.1                  40795.0            26895.0          481.0
#
#    Poverty Rate  Unemployment Rate  Time spent commuting (minutes)  \
# 0          24.7                1.9                             NaN
# 1           7.6                0.9                             NaN
# 2           9.8                3.2                             NaN
# 3          38.9                2.1                             NaN
# 4          20.6                1.6                             NaN
#
#    Number of Employed, age 16+  Unemployment Count  \
# 0                        885.0                34.0
# 1                       1500.0                17.0
# 2                       2366.0               151.0
# 3                        286.0                20.0
# 4                       1233.0                38.0
#
#    Number of persons age 25+ graduated high school
# 0                                            450.0
# 1                                             72.0
# 2                                           1231.0
# 3                                            229.0
# 4                                            394.0

# %%
census_pd.count()
# Out:
# State                                              200
# Name                                               200
# Population                                         200
# Median Age                                         200
# Median Household Income                            200
# Per Capita Income                                  200
# Poverty Count                                      200
# Poverty Rate                                       199
# Unemployment Rate                                  199
# Time spent commuting (minutes)                      16
# Number of Employed, age 16+                        200
# Unemployment Count                                 200
# Number of persons age 25+ graduated high school    200
# dtype: int64

# %%
census_pd[['Census_Tract', "County", "State Name"]]= census_pd['Name'].str.split(",", n=3, expand=True)
census_pd.head()
# Out:
#   State                                            Name  Population  \
# 0    24  Census Tract 2604.03, Baltimore city, Maryland      1764.0
# 1    24     Census Tract 2302, Baltimore city, Maryland      1982.0
# 2    24  Census Tract 2601.02, Baltimore city, Maryland      4775.0
# 3    24  Census Tract 2603.03, Baltimore city, Maryland       969.0
# 4    24     Census Tract 2608, Baltimore city, Maryland      2332.0
#
#    Median Age  Median Household Income  Per Capita Income  Poverty Count  \
# 0        27.9                  31625.0            21744.0          436.0
# 1        30.7                 107391.0            63973.0          151.0
# 2        41.3                  62586.0            25903.0          469.0
# 3        37.0                  17000.0            19562.0          377.0
# 4        36.1                  40795.0            26895.0          481.0
#
#    Poverty Rate  Unemployment Rate  Time spent commuting (minutes)  \
# 0          24.7                1.9                             NaN
# 1           7.6                0.9                             NaN
# 2           9.8                3.2                             NaN
# 3          38.9                2.1                             NaN
# 4          20.6                1.6                             NaN
#
#    Number of Employed, age 16+  Unemployment Count  \
# 0                        885.0                34.0
# 1                       1500.0                17.0
# 2                       2366.0               151.0
# 3                        286.0                20.0
# 4                       1233.0                38.0
#
#    Number of persons age 25+ graduated high school          Census_Tract  \
# 0                                            450.0  Census Tract 2604.03
# 1                                             72.0     Census Tract 2302
# 2                                           1231.0  Census Tract 2601.02
# 3                                            229.0  Census Tract 2603.03
# 4                                            394.0     Census Tract 2608
#
#             County State Name
# 0   Baltimore city   Maryland
# 1   Baltimore city   Maryland
# 2   Baltimore city   Maryland
# 3   Baltimore city   Maryland
# 4   Baltimore city   Maryland

# %%
census_pd = census_pd.drop(["State"], axis=1)
census_pd.head()
# Out:
#                                              Name  Population  Median Age  \
# 0  Census Tract 2604.03, Baltimore city, Maryland      1764.0        27.9
# 1     Census Tract 2302, Baltimore city, Maryland      1982.0        30.7
# 2  Census Tract 2601.02, Baltimore city, Maryland      4775.0        41.3
# 3  Census Tract 2603.03, Baltimore city, Maryland       969.0        37.0
# 4     Census Tract 2608, Baltimore city, Maryland      2332.0        36.1
#
#    Median Household Income  Per Capita Income  Poverty Count  Poverty Rate  \
# 0                  31625.0            21744.0          436.0          24.7
# 1                 107391.0            63973.0          151.0           7.6
# 2                  62586.0            25903.0          469.0           9.8
# 3                  17000.0            19562.0          377.0          38.9
# 4                  40795.0            26895.0          481.0          20.6
#
#    Unemployment Rate  Time spent commuting (minutes)  \
# 0                1.9                             NaN
# 1                0.9                             NaN
# 2                3.2                             NaN
# 3                2.1                             NaN
# 4                1.6                             NaN
#
#    Number of Employed, age 16+  Unemployment Count  \
# 0                        885.0                34.0
# 1                       1500.0                17.0
# 2                       2366.0               151.0
# 3                        286.0                20.0
# 4                       1233.0                38.0
#
#    Number of persons age 25+ graduated high school          Census_Tract  \
# 0                                            450.0  Census Tract 2604.03
# 1                                             72.0     Census Tract 2302
# 2                                           1231.0  Census Tract 2601.02
# 3                                            229.0  Census Tract 2603.03
# 4                                            394.0     Census Tract 2608
#
#             County State Name
# 0   Baltimore city   Maryland
# 1   Baltimore city   Maryland
# 2   Baltimore city   Maryland
# 3   Baltimore city   Maryland
# 4   Baltimore city   Maryland

# %%
census_pd.columns
# Out:
# Index(['Name', 'Population', 'Median Age', 'Median Household Income',
#        'Per Capita Income', 'Poverty Count', 'Poverty Rate',
#        'Unemployment Rate', 'Time spent commuting (minutes)',
#        'Number of Employed, age 16+', 'Unemployment Count',
#        'Number of persons age 25+ graduated high school', 'Census_Tract',
#        'County', 'State Name'],
#       dtype='object')

# %%
# Reorganize the columns using double brackets
census_pd = census_pd[["State Name","County","Census_Tract","Population",'Median Age', 'Median Household Income', 'Per Capita Income',
       'Poverty Count', 'Poverty Rate', 'Unemployment Rate',
       'Time spent commuting (minutes)', 'Number of Employed, age 16+',
       'Unemployment Count', 'Number of persons age 25+ graduated high school']]
census_pd
# Out:
#     State Name           County          Census_Tract  Population  Median Age  \
# 0     Maryland   Baltimore city  Census Tract 2604.03      1764.0        27.9
# 1     Maryland   Baltimore city     Census Tract 2302      1982.0        30.7
# 2     Maryland   Baltimore city  Census Tract 2601.02      4775.0        41.3
# 3     Maryland   Baltimore city  Census Tract 2603.03       969.0        37.0
# 4     Maryland   Baltimore city     Census Tract 2608      2332.0        36.1
# ..         ...              ...                   ...         ...         ...
# 195   Maryland   Baltimore city     Census Tract 2201      4447.0        33.1
# 196   Maryland   Baltimore city     Census Tract 2303      1408.0        30.7
# 197   Maryland   Baltimore city  Census Tract 2502.07      2337.0        32.5
# 198   Maryland   Baltimore city  Census Tract 2503.03      2229.0        37.0
# 199   Maryland   Baltimore city  Census Tract 2602.02      5681.0        31.8
#
#      Median Household Income  Per Capita Income  Poverty Count  Poverty Rate  \
# 0                    31625.0            21744.0          436.0          24.7
# 1                   107391.0            63973.0          151.0           7.6
# 2                    62586.0            25903.0          469.0           9.8
# 3                    17000.0            19562.0          377.0          38.9
# 4                    40795.0            26895.0          481.0          20.6
# ..                       ...                ...            ...           ...
# 195                  80129.0            67973.0          539.0          12.1
# 196                 104250.0            61852.0          117.0           8.3
# 197                  38194.0            20012.0          691.0          29.6
# 198                  38519.0            24608.0          568.0          25.5
# 199                  41538.0            25897.0          914.0          16.1
#
#      Unemployment Rate  Time spent commuting (minutes)  \
# 0                  1.9                             NaN
# 1                  0.9                             NaN
# 2                  3.2                             NaN
# 3                  2.1                             NaN
# 4                  1.6                             NaN
# ..                 ...                             ...
# 195                1.9                             NaN
# 196                1.1                             NaN
# 197                4.5                             NaN
# 198                6.7                             NaN
# 199                5.5                             NaN
#
#      Number of Employed, age 16+  Unemployment Count  \
# 0                          885.0                34.0
# 1                         1500.0                17.0
# 2                         2366.0               151.0
# 3                          286.0                20.0
# 4                         1233.0                38.0
# ..                           ...                 ...
# 195                       2762.0                83.0
# 196                       1161.0                15.0
# 197                        916.0               106.0
# 198                        935.0               149.0
# 199                       2801.0               312.0
#
#      Number of persons age 25+ graduated high school
# 0                                              450.0
# 1                                               72.0
# 2                                             1231.0
# 3                                              229.0
# 4                                              394.0
# ..                                               ...
# 195                                            255.0
# 196                                             91.0
# 197                                            512.0
# 198                                            425.0
# 199                                           1197.0
#
# [200 rows x 14 columns]

# %%
census_pd["Census_Tract"] = census_pd['Census_Tract'].str.replace('Census Tract', "") 
census_pd
# Out:
#     State Name           County Census_Tract  Population  Median Age  \
# 0     Maryland   Baltimore city      2604.03      1764.0        27.9
# 1     Maryland   Baltimore city         2302      1982.0        30.7
# 2     Maryland   Baltimore city      2601.02      4775.0        41.3
# 3     Maryland   Baltimore city      2603.03       969.0        37.0
# 4     Maryland   Baltimore city         2608      2332.0        36.1
# ..         ...              ...          ...         ...         ...
# 195   Maryland   Baltimore city         2201      4447.0        33.1
# 196   Maryland   Baltimore city         2303      1408.0        30.7
# 197   Maryland   Baltimore city      2502.07      2337.0        32.5
# 198   Maryland   Baltimore city      2503.03      2229.0        37.0
# 199   Maryland   Baltimore city      2602.02      5681.0        31.8
#
#      Median Household Income  Per Capita Income  Poverty Count  Poverty Rate  \
# 0                    31625.0            21744.0          436.0          24.7
# 1                   107391.0            63973.0          151.0           7.6
# 2                    62586.0            25903.0          469.0           9.8
# 3                    17000.0            19562.0          377.0          38.9
# 4                    40795.0            26895.0          481.0          20.6
# ..                       ...                ...            ...           ...
# 195                  80129.0            67973.0          539.0          12.1
# 196                 104250.0            61852.0          117.0           8.3
# 197                  38194.0            20012.0          691.0          29.6
# 198                  38519.0            24608.0          568.0          25.5
# 199                  41538.0            25897.0          914.0          16.1
#
#      Unemployment Rate  Time spent commuting (minutes)  \
# 0                  1.9                             NaN
# 1                  0.9                             NaN
# 2                  3.2                             NaN
# 3                  2.1                             NaN
# 4                  1.6                             NaN
# ..                 ...                             ...
# 195                1.9                             NaN
# 196                1.1                             NaN
# 197                4.5                             NaN
# 198                6.7                             NaN
# 199                5.5                             NaN
#
#      Number of Employed, age 16+  Unemployment Count  \
# 0                          885.0                34.0
# 1                         1500.0                17.0
# 2                         2366.0               151.0
# 3                          286.0                20.0
# 4                         1233.0                38.0
# ..                           ...                 ...
# 195                       2762.0                83.0
# 196                       1161.0                15.0
# 197                        916.0               106.0
# 198                        935.0               149.0
# 199                       2801.0               312.0
#
#      Number of persons age 25+ graduated high school
# 0                                              450.0
# 1                                               72.0
# 2                                             1231.0
# 3                                              229.0
# 4                                              394.0
# ..                                               ...
# 195                                            255.0
# 196                                             91.0
# 197                                            512.0
# 198                                            425.0
# 199                                           1197.0
#
# [200 rows x 14 columns]

# %%
# Calculations can also be performed on Series and added into DataFrames as new columns
#thousands_of_dollars = data_file_df["Amount"]/1000
#data_file_df["Thousands of Dollars"] = thousands_of_dollars

#data_file_df.head()

# %%
# Converting the membership days into weeks and then adding a column to the DataFrame
#weeks = training_df["Membership (Days)"]/7
#training_df["Membership (Weeks)"] = weeks

#training_df.head()

# %%
# Calculate the number of unique census tracts in the DataFrame
tract_count = len(census_pd["Census_Tract"].unique())
tract_count
# Out:
# 200

# %%
# Export file as a CSV, without the Pandas index, but with the header
census_pd.to_csv("Comm_Corridor_Stats_Draft1.csv", index = False, header=True)
